# %%
import keras_ocr
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
images=[keras_ocr.tools.read(img) for img in(["resim3.jpg"])]
# Out:
# Looking for C:\Users\ipek\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\ipek\.keras-ocr\crnn_kurapan.h5

# %%
images
# Out:
# [array([[[119, 127, 130],
#          [ 88,  96,  99],
#          [ 82,  90,  93],
#          ...,
#          [163, 176, 185],
#          [162, 175, 184],
#          [162, 175, 184]],
#
#         [[101, 109, 112],
#          [ 86,  94,  97],
#          [ 88,  96,  99],
#          ...,
#          [162, 175, 184],
#          [161, 174, 183],
#          [161, 174, 183]],
#
#         [[ 94,  99, 103],
#          [ 98, 103, 107],
#          [108, 113, 117],
#          ...,
#          [162, 175, 184],
#          [160, 173, 182],
#          [159, 172, 181]],
#
#         ...,
#
#         [[ 25,  32,  50],
#          [ 24,  31,  49],
#          [ 23,  30,  48],
#          ...,
#          [ 11,  32,  59],
#          [ 10,  31,  58],
#          [ 10,  31,  58]],
#
#         [[ 25,  32,  50],
#          [ 24,  31,  49],
#          [ 23,  30,  48],
#          ...,
#          [  3,  24,  51],
#          [  3,  24,  51],
#          [  4,  25,  52]],
#
#         [[ 25,  32,  50],
# ...

# %%
predictions = pipeline.recognize(images)
# Out:
# ...
# 1/1 [==============================] - 2s 2s/step

# %%
fig,ax=plt.subplots(figsize=(8,8))
for image,predictions in zip(images,predictions):
    keras_ocr.tools.drawAnnotations(image=image,predictions=predictions,ax=ax)

# %%
#blurred img
blurred_img = cv2.GaussianBlur(image,(15,15),0)
predictions = pipeline.recognize([blurred_img])
# Out:
# ...
# 1/1 [==============================] - 0s 100ms/step

# %%
fig, ax = plt.subplots(figsize=(18, 18))
keras_ocr.tools.drawAnnotations(image=blurred_img, predictions=predictions[0], ax=ax)
# Out:
# <Axes: >
